# %%
# contracts_processing.py

import sys
import os

# Add the config directory to the Python path
CONFIG_DIR = r'C:\Users\ak012\Documents\Projects\config'
if CONFIG_DIR not in sys.path:
    sys.path.append(CONFIG_DIR)

import config  # Now you can import config from the specified directory

import pandas as pd
import numpy as np
from pymongo import MongoClient, UpdateOne
from datetime import datetime, timezone
import logging
from tqdm import tqdm
from dotenv import load_dotenv

# ==============================
# 1. Load Environment Variables
# ==============================
load_dotenv()

# ==============================
# 2. Configure Logging
# ==============================
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.StreamHandler(),
        logging.FileHandler("contract_processing.log")
    ]
)
logger = logging.getLogger()

# ==============================
# 3. MongoDB Connection Details
# ==============================
MONGO_URI = ('Insert-here-')  
if not MONGO_URI:
    logger.error("MONGO_URI not found in environment variables.")
    sys.exit(1)

DATABASE_NAME = "legitt-prod"
CONTRACTS_COLLECTION = "company_contracts"

# ==============================
# 4. Helper Functions
# ==============================
def calculate_interference(contract_row, apply_coverage_ratio):
    overdue_days = contract_row.get('overdue_days', 0)
    status_score = 0 if contract_row.get('status', '').strip().lower() == "completed" else 20
    overdue_multiplier = 0 if overdue_days < 61 else config.OVERDUE_MULTIPLIER  # Updated to use config
    base_score = overdue_days * overdue_multiplier + status_score

    if apply_coverage_ratio:
        coverage_ratio = contract_row.get('coverage_ratio', 1.0)
        coverage_penalty = (1 - coverage_ratio) * config.COVERAGE_PENALTY_WEIGHT if coverage_ratio < 1 else 0  # Updated to use config
        return base_score + coverage_penalty

    return base_score

def assign_rating(score):
    """Assign rating based on interference score using config thresholds."""
    if score < config.SCORE_THRESHOLD_GREEN:  # Updated to use config
        return "Green"
    elif config.SCORE_THRESHOLD_GREEN <= score < config.SCORE_THRESHOLD_YELLOW:  # Updated to use config
        return "Yellow"
    else:
        return "Red"

def calculate_actual_contract_value_today(row, today):
    contract_value = row.get('contract_value', 0)
    total_renewal_amount = row.get('total_renewal_amount', 0)

    from_date = row.get('from_date')
    to_date = row.get('to_date')

    if pd.isnull(from_date) or pd.isnull(to_date):
        return contract_value + total_renewal_amount

    if today <= to_date:
        days_since_start = (today - from_date).days
        return (contract_value * days_since_start / 365) + total_renewal_amount

    return contract_value + total_renewal_amount

def calculate_total_renewals(contracts):
    renewal_mapping = {}
    for contract in contracts:
        contract_id = contract.get('contract_id', '')
        renewals = contract.get('renewals', [])
        total_renewal = sum(
            renewal.get('renewal_amount', 0) 
            for renewal in renewals 
            if isinstance(renewal.get('renewal_amount', 0), (int, float))
        )
        renewal_mapping[contract_id] = total_renewal
        logging.info(f"Contract '{contract_id}' has total renewals: {total_renewal}")
    return renewal_mapping

# ==============================
# 5. Helper Function for Milestones
# ==============================
def calculate_milestone_penalty(milestone_days_late):
    """Calculate penalty based on how many days a milestone is missed."""
    if milestone_days_late < config.MILESTONE_DAYS_THRESHOLD_3:
        return config.MILESTONE_PENALTY_LESS_THAN_3_DAYS
    elif config.MILESTONE_DAYS_THRESHOLD_3 <= milestone_days_late < config.MILESTONE_DAYS_THRESHOLD_5:
        return config.MILESTONE_PENALTY_LESS_THAN_5_DAYS
    elif config.MILESTONE_DAYS_THRESHOLD_5 <= milestone_days_late < config.MILESTONE_DAYS_THRESHOLD_7:
        return config.MILESTONE_PENALTY_LESS_THAN_7_DAYS
    else:
        return config.MILESTONE_PENALTY_MORE_THAN_7_DAYS

# ==============================
# 6. Main Processing Function
# ==============================
def process_invoices_and_contracts():
    # User input to apply coverage ratio
    apply_coverage_ratio_input = input("Do you want to apply coverage ratio to the interference rating? (yes/no): ").strip().lower()
    apply_coverage_ratio = apply_coverage_ratio_input == 'yes'

    # New User input to apply milestone penalties
    apply_milestone_penalty_input = input("Do you want to incorporate milestone penalties? (yes/no): ").strip().lower()
    apply_milestone_penalty = apply_milestone_penalty_input == 'yes'

    logging.info(f"Apply coverage ratio: {apply_coverage_ratio}")
    logging.info(f"Apply milestone penalties: {apply_milestone_penalty}")

    try:
        client = MongoClient(MONGO_URI)
        db = client[DATABASE_NAME]
        contracts_collection = db[CONTRACTS_COLLECTION]
        logging.info("Connected to MongoDB successfully.")
    except Exception as e:
        logging.error(f"Failed to connect to MongoDB: {e}")
        return

    try:
        contracts = list(contracts_collection.find())
        logging.info(f"Number of contracts fetched: {len(contracts)}")
    except Exception as e:
        logging.error(f"Error fetching contracts: {e}")
        return

    if not contracts:
        logging.info("No contracts to process.")
        return

    df_contracts = pd.DataFrame(contracts)
    today = datetime.now(timezone.utc)

    # Rename date columns if necessary
    if 'start_date' in df_contracts.columns and 'end_date' in df_contracts.columns:
        df_contracts.rename(columns={"start_date": "from_date", "end_date": "to_date"}, inplace=True)
        logging.info("Renamed 'start_date' to 'from_date' and 'end_date' to 'to_date'.")

    # Convert date columns to datetime
    contract_date_cols = ['from_date', 'to_date']
    for col in contract_date_cols:
        if col in df_contracts.columns:
            df_contracts[col] = pd.to_datetime(df_contracts[col], errors='coerce', utc=True)

    # Calculate total renewals
    renewal_mapping = calculate_total_renewals(contracts)
    df_contracts['total_renewal_amount'] = df_contracts['contract_id'].map(renewal_mapping).fillna(0.0)

    # Handle missing 'contract_value'
    if 'contract_value' not in df_contracts.columns:
        df_contracts['contract_value'] = 0.0
        logging.warning("'contract_value' column not found in contracts. Set to 0.0.")

    # Calculate actual contract value today
    df_contracts['actual_contract_value_today'] = df_contracts.apply(
        lambda row: calculate_actual_contract_value_today(row, today), axis=1
    )
    logging.info("Calculated 'actual_contract_value_today' for contracts.")

    # Calculate coverage ratio
    df_contracts['coverage_ratio'] = df_contracts['actual_contract_value_today'].apply(
        lambda x: 1 if x > 0 else 0
    )

    # ==============================
    # 7. Milestones Processing
    # ==============================
    if apply_milestone_penalty:
        milestones_file_path = r"C:\Users\ak012\Documents\Projects\Contracts\simulated_milestones.xlsx"
        try:
            df_milestones = pd.read_excel(milestones_file_path)
            logging.info(f"Milestones data loaded from {milestones_file_path}.")
        except Exception as e:
            logging.error(f"Error loading milestones Excel file: {e}")
            df_milestones = pd.DataFrame()  # Empty DataFrame to avoid further errors

        if not df_milestones.empty:
            # Ensure necessary columns exist
            required_columns = ['contract_name', 'milestone_due_date', 'completion_date']
            if all(col in df_milestones.columns for col in required_columns):
                df_milestones['milestone_due_date'] = pd.to_datetime(df_milestones['milestone_due_date'], errors='coerce', utc=True)
                df_milestones['completion_date'] = pd.to_datetime(df_milestones['completion_date'], errors='coerce', utc=True)

                # Calculate days late for each milestone
                df_milestones['days_late'] = (df_milestones['completion_date'] - df_milestones['milestone_due_date']).dt.days
                df_milestones['days_late'] = df_milestones['days_late'].apply(lambda x: x if x > 0 else 0)

                # Calculate penalties
                df_milestones['milestone_penalty'] = df_milestones['days_late'].apply(calculate_milestone_penalty)

                # Aggregate penalties per contract
                penalty_mapping = df_milestones.groupby('contract_name')['milestone_penalty'].sum().to_dict()
                df_contracts['milestone_penalty'] = df_contracts['contract_name'].map(penalty_mapping).fillna(0.0)
                logging.info("Calculated milestone penalties for contracts.")
            else:
                logging.error(f"Milestones Excel file is missing required columns: {required_columns}")
                df_contracts['milestone_penalty'] = 0.0
        else:
            df_contracts['milestone_penalty'] = 0.0
            logging.info("No milestones data to process.")
    else:
        # If milestone penalties are not applied, set penalties to 0
        df_contracts['milestone_penalty'] = 0.0
        logging.info("Milestone penalties are not applied as per user input.")

    # ==============================
    # 8. Calculate Interference Score
    # ==============================
    df_contracts['final_interference_score'] = df_contracts.apply(
        lambda row: calculate_interference(row, apply_coverage_ratio) + row.get('milestone_penalty', 0),
        axis=1
    )
    logging.info("Calculated 'final_interference_score' for contracts, including milestone penalties if applied.")

    # Assign ratings based on interference_score
    df_contracts['final_rating'] = df_contracts['final_interference_score'].apply(assign_rating)
    logging.info("Assigned 'final_rating' based on interference scores.")

    # ==============================
    # 9. Save to Excel
    # ==============================
    output_excel = r"C:\\Users\\ak012\\Documents\\Projects\\Contracts\\processed_contracts.xlsx"

    if 'df_contracts' in locals() and not df_contracts.empty:
        # Remove timezone information from datetime columns
        datetime_cols = df_contracts.select_dtypes(include=['datetime64[ns, UTC]']).columns
        for col in datetime_cols:
            df_contracts[col] = df_contracts[col].dt.tz_localize(None)

        try:
            df_contracts.to_excel(output_excel, index=False)
            logging.info(f"Processed data saved to Excel: {output_excel}")
        except Exception as e:
            logging.error(f"Error saving Excel file: {e}")
    else:
        logging.error("DataFrame 'df_contracts' is not defined or is empty.")

    # ==============================
    # 10. Close MongoDB Connection
    # ==============================
    try:
        client.close()
        logging.info("Closed MongoDB connection.")
    except Exception as e:
        logging.error(f"Error closing MongoDB connection: {e}")

if __name__ == "__main__":
    process_invoices_and_contracts()
# Out:
# 2024-12-27 11:35:26,544 - INFO - Apply coverage ratio: True
# 2024-12-27 11:35:26,546 - INFO - Apply milestone penalties: False
# 2024-12-27 11:35:26,843 - INFO - Connected to MongoDB successfully.
# 2024-12-27 11:36:36,662 - INFO - Number of contracts fetched: 7652
# 2024-12-27 11:36:36,799 - INFO - Renamed 'start_date' to 'from_date' and 'end_date' to 'to_date'.
# 2024-12-27 11:36:36,846 - INFO - Contract '8002s000000cF4kAAE' has total renewals: 0
# 2024-12-27 11:36:36,848 - INFO - Contract '8002s000000cF3cAAE' has total renewals: 0
# 2024-12-27 11:36:36,850 - INFO - Contract '8002s000000cF7MAAU' has total renewals: 0
# 2024-12-27 11:36:36,851 - INFO - Contract '8006F000000Se44QAC' has total renewals: 4572
# 2024-12-27 11:36:36,852 - INFO - Contract '8002s000000lxrAAAQ' has total renewals: 442
# 2024-12-27 11:36:36,853 - INFO - Contract '8006F000000XlzDQAS' has total renewals: 0
# 2024-12-27 11:36:36,855 - INFO - Contract '8006F000000nU9AQAU' has total renewals: 0
# 2024-12-27 11:36:36,856 - INFO - Contract '800Sz000005S4gvIAC' has total renewals: 275
# 2024-12-27 11:36:36,858 - INFO - Contract '8006F0000014ircQAA' has total renewals: 0
# 2024-12-27 11:36:36,860 - INFO - Contract '800C60000000UHXIA2' has total renewals: 600
# 2024-12-27 11:36:36,862 - INFO - Contract '800C60000000Sw3IAE' has total renewals: 4050
# 2024-12-27 11:36:36,863 - INFO - Contract '8006F000001UduXQAS' has total renewals: 4640
# 2024-12-27 11:36:36,864 - INFO - Contract '8002s000000XsE5AAK' has total renewals: 0
# 2024-12-27 11:36:36,865 - INFO - Contract '8002s000000cBafAAE' has total renewals: 0
# 2024-12-27 11:36:36,867 - INFO - Contract '8002s000000DCKSAA4' has total renewals: 0
# 2024-12-27 11:36:36,868 - INFO - Contract '8002s000000cBdvAAE' has total renewals: 0
# 2024-12-27 11:36:36,869 - INFO - Contract '8002s000000cEzLAAU' has total renewals: 977
# 2024-12-27 11:36:36,871 - INFO - Contract '8002s000000cBROAA2' has total renewals: 0
# 2024-12-27 11:36:36,872 - INFO - Contract '8002s000000cBREAA2' has total renewals: 0
# 2024-12-27 11:36:36,874 - INFO - Contract '8002s000000cF4fAAE' has total renewals: 0
# 2024-12-27 11:36:36,876 - INFO - Contract '8002s000000cBAYAA2' has total renewals: 0
# 2024-12-27 11:36:36,876 - INFO - Contract '8002s000000cF5sAAE' has total renewals: 0
# 2024-12-27 11:36:36,877 - INFO - Contract '8002s000000cEzGAAU' has total renewals: 977
# 2024-12-27 11:36:36,879 - INFO - Contract '8002s000000cF77AAE' has total renewals: 0
# 2024-12-27 11:36:36,880 - INFO - Contract '8002s000000cF7fAAE' has total renewals: 0
# 2024-12-27 11:36:36,882 - INFO - Contract '8002s000000cF6OAAU' has total renewals: 0
# 2024-12-27 11:36:36,883 - INFO - Contract '8002s000000cF7GAAU' has total renewals: 0
# 2024-12-27 11:36:36,884 - INFO - Contract '8002s000000cF7NAAU' has total renewals: 0
# 2024-12-27 11:36:36,886 - INFO - Contract '8002s000000cF7HAAU' has total renewals: 0
# 2024-12-27 11:36:36,887 - INFO - Contract '8002s000000cF7QAAU' has total renewals: 0
# 2024-12-27 11:36:36,888 - INFO - Contract '8002s000000cF7OAAU' has total renewals: 0
# 2024-12-27 11:36:36,889 - INFO - Contract '8002s000000cF7VAAU' has total renewals: 0
# 2024-12-27 11:36:36,890 - INFO - Contract '8002s000000cF7RAAU' has total renewals: 0
# 2024-12-27 11:36:36,891 - INFO - Contract '8002s000000lxqqAAA' has total renewals: 0
# 2024-12-27 11:36:36,893 - INFO - Contract '8002s000000cF7WAAU' has total renewals: 0
# 2024-12-27 11:36:36,894 - INFO - Contract '8002s000000cF93AAE' has total renewals: 0
# 2024-12-27 11:36:36,896 - INFO - Contract '8002s000000cHP4AAM' has total renewals: 0
# 2024-12-27 11:36:36,897 - INFO - Contract '8002s000000lxswAAA' has total renewals: 0
# 2024-12-27 11:36:36,898 - INFO - Contract '8002s000000cF7LAAU' has total renewals: 0
# 2024-12-27 11:36:36,899 - INFO - Contract '8002s000000lxrKAAQ' has total renewals: 0
# 2024-12-27 11:36:36,901 - INFO - Contract '8002s000000lxshAAA' has total renewals: 0
# 2024-12-27 11:36:36,902 - INFO - Contract '8002s000000cF7KAAU' has total renewals: 0
# 2024-12-27 11:36:36,903 - INFO - Contract '8002s000000cF7JAAU' has total renewals: 0
# 2024-12-27 11:36:36,905 - INFO - Contract '8002s000000lzhCAAQ' has total renewals: 0
# 2024-12-27 11:36:36,905 - INFO - Contract '8002s000000lyxyAAA' has total renewals: 0
# 2024-12-27 11:36:36,906 - INFO - Contract '8002s000000lxs8AAA' has total renewals: 0
# 2024-12-27 11:36:36,907 - INFO - Contract '8002s000000lxs3AAA' has total renewals: 0
# 2024-12-27 11:36:36,909 - INFO - Contract '8002s000000cF7UAAU' has total renewals: 0
# 2024-12-27 11:36:36,911 - INFO - Contract '8002s000000lxr5AAA' has total renewals: 442
# 2024-12-27 11:36:36,913 - INFO - Contract '8002s000000cF7PAAU' has total renewals: 0
# 2024-12-27 11:36:36,914 - INFO - Contract '8002s000000cF7EAAU' has total renewals: 0
# 2024-12-27 11:36:36,915 - INFO - Contract '8002s000000cF7SAAU' has total renewals: 0
# 2024-12-27 11:36:36,917 - INFO - Contract '8006F000000Xll6QAC' has total renewals: 0
# 2024-12-27 11:36:36,918 - INFO - Contract '8006F000000SpgyQAC' has total renewals: 0
# 2024-12-27 11:36:36,920 - INFO - Contract '8006F000000XpPmQAK' has total renewals: 0
# 2024-12-27 11:36:36,921 - INFO - Contract '8006F0000014gkfQAA' has total renewals: 0
# 2024-12-27 11:36:36,922 - INFO - Contract '8006F000000XqyCQAS' has total renewals: 0
# 2024-12-27 11:36:36,923 - INFO - Contract '8006F000000Xqy2QAC' has total renewals: 0
# 2024-12-27 11:36:36,924 - INFO - Contract '8006F000000nU9PQAU' has total renewals: 0
# 2024-12-27 11:36:36,925 - INFO - Contract '8006F0000014hYmQAI' has total renewals: 0
# 2024-12-27 11:36:36,926 - INFO - Contract '8006F000000XlQ8QAK' has total renewals: 2079
# 2024-12-27 11:36:36,927 - INFO - Contract '8006F000001TSZRQA4' has total renewals: 0
# 2024-12-27 11:36:36,928 - INFO - Contract '8006F000000nTYdQAM' has total renewals: 0
# 2024-12-27 11:36:36,929 - INFO - Contract '8006F000001TQyhQAG' has total renewals: 0
# 2024-12-27 11:36:36,930 - INFO - Contract '8006F000001ZarvQAC' has total renewals: 0
# 2024-12-27 11:36:36,930 - INFO - Contract '800C60000000QyqIAE' has total renewals: 0
# 2024-12-27 11:36:36,933 - INFO - Contract '800C60000000SqxIAE' has total renewals: 0
# 2024-12-27 11:36:36,934 - INFO - Contract '800C60000000SwSIAU' has total renewals: 0
# 2024-12-27 11:36:36,935 - INFO - Contract '8006F000001ZaJUQA0' has total renewals: 0
# 2024-12-27 11:36:36,936 - INFO - Contract '8002s000000lxscAAA' has total renewals: 31200
# 2024-12-27 11:36:36,938 - INFO - Contract '8006F000000SlyRQAS' has total renewals: 11700
# 2024-12-27 11:36:36,940 - INFO - Contract '8006F000000XlhxQAC' has total renewals: 2079
# 2024-12-27 11:36:36,942 - INFO - Contract '8006F000000XlQ3QAK' has total renewals: 1539
# 2024-12-27 11:36:36,944 - INFO - Contract '8006F000000XlPyQAK' has total renewals: 2442
# 2024-12-27 11:36:36,946 - INFO - Contract '8006F000000XkhSQAS' has total renewals: 5641
# 2024-12-27 11:36:36,947 - INFO - Contract '8006F0000010iGxQAI' has total renewals: 9800
# 2024-12-27 11:36:36,948 - INFO - Contract '8006F000001ZaAhQAK' has total renewals: 0
# 2024-12-27 11:36:36,949 - INFO - Contract '8006F0000019yZFQAY' has total renewals: 6000
# 2024-12-27 11:36:36,950 - INFO - Contract '8006F000000XqxxQAC' has total renewals: 20000
# 2024-12-27 11:36:36,951 - INFO - Contract '8006F0000019yZAQAY' has total renewals: 11200
# 2024-12-27 11:36:36,953 - INFO - Contract '8006F0000016DYsQAM' has total renewals: 1750
# 2024-12-27 11:36:36,955 - INFO - Contract '800C60000000VHDIA2' has total renewals: 1100
# 2024-12-27 11:36:36,956 - INFO - Contract '8006F000001ZbrIQAS' has total renewals: 14400
# 2024-12-27 11:36:36,957 - INFO - Contract '800C60000000LV5IAM' has total renewals: 3300
# 2024-12-27 11:36:36,959 - INFO - Contract '800C60000000dC1IAI' has total renewals: 0
# 2024-12-27 11:36:36,961 - INFO - Contract '8006F000001TgipQAC' has total renewals: 1500
# 2024-12-27 11:36:36,962 - INFO - Contract '800C60000000XfVIAU' has total renewals: 1200
# 2024-12-27 11:36:36,963 - INFO - Contract '800C60000000WoBIAU' has total renewals: 1100
# 2024-12-27 11:36:36,964 - INFO - Contract '8006F000001ZaeDQAS' has total renewals: 0
# 2024-12-27 11:36:36,966 - INFO - Contract '800C60000000Wo6IAE' has total renewals: 2000
# 2024-12-27 11:36:36,968 - INFO - Contract '8006F000000SnpOQAS' has total renewals: 0
# 2024-12-27 11:36:36,969 - INFO - Contract '8002s000000cEz3AAE' has total renewals: 3000
# 2024-12-27 11:36:36,970 - INFO - Contract '8006F000000SfeRQAS' has total renewals: 900
# 2024-12-27 11:36:36,971 - INFO - Contract '8006F000000nFF1QAM' has total renewals: 0
# 2024-12-27 11:36:36,972 - INFO - Contract '8006F000001RpDIQA0' has total renewals: 1400
# 2024-12-27 11:36:36,974 - INFO - Contract '8006F000001ZaJKQA0' has total renewals: 0
# 2024-12-27 11:36:36,975 - INFO - Contract '8006F0000016DYnQAM' has total renewals: 1750
# 2024-12-27 11:36:36,977 - INFO - Contract '8006F000000nBMRQA2' has total renewals: 8150
# 2024-12-27 11:36:36,978 - INFO - Contract '8006F000001ZbrNQAS' has total renewals: 0
# 2024-12-27 11:36:36,980 - INFO - Contract '8002s000000XrdSAAS' has total renewals: 6850
# 2024-12-27 11:36:36,981 - INFO - Contract '8002s000000cBdrAAE' has total renewals: 0
# 2024-12-27 11:36:36,982 - INFO - Contract '8002s000000cE3QAAU' has total renewals: 0
# 2024-12-27 11:36:36,983 - INFO - Contract '8002s000000cF7mAAE' has total renewals: 0
# 2024-12-27 11:36:36,984 - INFO - Contract '800900000009sziAAA' has total renewals: 0
# 2024-12-27 11:36:36,985 - INFO - Contract '800Sz000002bXGnIAM' has total renewals: 399
# 2024-12-27 11:36:36,986 - INFO - Contract '800900000009szsAAA' has total renewals: 0
# 2024-12-27 11:36:36,987 - INFO - Contract '8002s000000cBdjAAE' has total renewals: 0
# 2024-12-27 11:36:36,989 - INFO - Contract '8002s000000XrYtAAK' has total renewals: 0
# 2024-12-27 11:36:36,991 - INFO - Contract '8002s000000cBdfAAE' has total renewals: 0
# 2024-12-27 11:36:36,993 - INFO - Contract '8002s000000cBdhAAE' has total renewals: 0
# 2024-12-27 11:36:36,994 - INFO - Contract '8002s000000cBddAAE' has total renewals: 0
# 2024-12-27 11:36:36,996 - INFO - Contract '8002s000000cBdbAAE' has total renewals: 0
# 2024-12-27 11:36:36,996 - INFO - Contract '8002s000000cBdcAAE' has total renewals: 0
# 2024-12-27 11:36:36,997 - INFO - Contract '8002s000000cBdiAAE' has total renewals: 0
# 2024-12-27 11:36:36,998 - INFO - Contract '8002s000000cBdgAAE' has total renewals: 0
# 2024-12-27 11:36:36,999 - INFO - Contract '8002s000000cBduAAE' has total renewals: 0
# 2024-12-27 11:36:37,000 - INFO - Contract '8002s000000cBdmAAE' has total renewals: 0
# 2024-12-27 11:36:37,002 - INFO - Contract '8002s000000cBdoAAE' has total renewals: 0
# 2024-12-27 11:36:37,003 - INFO - Contract '8002s000000cBdnAAE' has total renewals: 0
# 2024-12-27 11:36:37,005 - INFO - Contract '8002s000000cC8XAAU' has total renewals: 0
# 2024-12-27 11:36:37,006 - INFO - Contract '8002s000000cBdkAAE' has total renewals: 0
# 2024-12-27 11:36:37,007 - INFO - Contract '8002s000000cBdsAAE' has total renewals: 0
# 2024-12-27 11:36:37,008 - INFO - Contract '8002s000000cF7jAAE' has total renewals: 0
# 2024-12-27 11:36:37,009 - INFO - Contract '8002s000000cFCbAAM' has total renewals: 0
# 2024-12-27 11:36:37,011 - INFO - Contract '8002s000000cBdtAAE' has total renewals: 0
# 2024-12-27 11:36:37,013 - INFO - Contract '8002s000000cF8qAAE' has total renewals: 0
# 2024-12-27 11:36:37,014 - INFO - Contract '8002s000000cG8bAAE' has total renewals: 8000
# 2024-12-27 11:36:37,015 - INFO - Contract '8002s000000lzCGAAY' has total renewals: 3000
# 2024-12-27 11:36:37,017 - INFO - Contract '8002s000000cF7xAAE' has total renewals: 62400
# 2024-12-27 11:36:37,019 - INFO - Contract '8006F000000XmM7QAK' has total renewals: 0
# 2024-12-27 11:36:37,020 - INFO - Contract '8006F000001A7qCQAS' has total renewals: 0
# 2024-12-27 11:36:37,021 - INFO - Contract '8002s000000m0DbAAI' has total renewals: 0
# 2024-12-27 11:36:37,022 - INFO - Contract '8006F000000nNLiQAM' has total renewals: 0
# 2024-12-27 11:36:37,023 - INFO - Contract '8002s000000lziPAAQ' has total renewals: 1200
# 2024-12-27 11:36:37,025 - INFO - Contract '8002s000000cBdpAAE' has total renewals: 0
# 2024-12-27 11:36:37,027 - INFO - Contract '8002s000000cF7lAAE' has total renewals: 0
# 2024-12-27 11:36:37,029 - INFO - Contract '8006F000000XmLxQAK' has total renewals: 0
# 2024-12-27 11:36:37,030 - INFO - Contract '8002s000000m04YAAQ' has total renewals: 1800
# 2024-12-27 11:36:37,031 - INFO - Contract '8002s000000m052AAA' has total renewals: 600
# 2024-12-27 11:36:37,032 - INFO - Contract '8006F000000XmMRQA0' has total renewals: 0
# 2024-12-27 11:36:37,033 - INFO - Contract '8002s000000m04nAAA' has total renewals: 600
# 2024-12-27 11:36:37,034 - INFO - Contract '8002s000000cFcTAAU' has total renewals: 31200
# 2024-12-27 11:36:37,035 - INFO - Contract '8006F000001A7reQAC' has total renewals: 3000
# 2024-12-27 11:36:37,037 - INFO - Contract '8006F000001A7rZQAS' has total renewals: 5000
# 2024-12-27 11:36:37,038 - INFO - Contract '8002s000000m0DzAAI' has total renewals: 0
# 2024-12-27 11:36:37,040 - INFO - Contract '8006F000001Zc9gQAC' has total renewals: 0
# 2024-12-27 11:36:37,042 - INFO - Contract '8002s000000cFCYAA2' has total renewals: 0
# 2024-12-27 11:36:37,043 - INFO - Contract '8006F000000nFziQAE' has total renewals: 0
# 2024-12-27 11:36:37,044 - INFO - Contract '8006F000000SgWsQAK' has total renewals: 2000
# 2024-12-27 11:36:37,045 - INFO - Contract '800900000009sznAAA' has total renewals: 0
# 2024-12-27 11:36:37,047 - INFO - Contract '8006F000001TRcDQAW' has total renewals: 0
# 2024-12-27 11:36:37,048 - INFO - Contract '8006F000000SgVpQAK' has total renewals: 6937.54
# 2024-12-27 11:36:37,050 - INFO - Contract '8006F000000Sgi8QAC' has total renewals: 0
# 2024-12-27 11:36:37,051 - INFO - Contract '8006F000001Zc9vQAC' has total renewals: 0
# 2024-12-27 11:36:37,052 - INFO - Contract '8006F000000SgVkQAK' has total renewals: 4937.5
# 2024-12-27 11:36:37,053 - INFO - Contract '8006F000000SgVzQAK' has total renewals: 3937.5
# 2024-12-27 11:36:37,055 - INFO - Contract '8006F000001A83PQAS' has total renewals: 0
# 2024-12-27 11:36:37,055 - INFO - Contract '800C60000000OkqIAE' has total renewals: 0
# 2024-12-27 11:36:37,057 - INFO - Contract '8006F000001TRcBQAW' has total renewals: 0
# 2024-12-27 11:36:37,058 - INFO - Contract '8006F000001Zbe4QAC' has total renewals: 0
# 2024-12-27 11:36:37,060 - INFO - Contract '8006F000001ZaxFQAS' has total renewals: 0
# 2024-12-27 11:36:37,062 - INFO - Contract '800Sz000004D5kOIAS' has total renewals: 0
# 2024-12-27 11:36:37,064 - INFO - Contract '800Sz000004CzZ9IAK' has total renewals: 0
# 2024-12-27 11:36:37,065 - INFO - Contract '8006F000001TRcCQAW' has total renewals: 0
# 2024-12-27 11:36:37,068 - INFO - Contract '800C60000000L7EIAU' has total renewals: 600
# 2024-12-27 11:36:37,069 - INFO - Contract '800C60000000L7JIAU' has total renewals: 600
# 2024-12-27 11:36:37,070 - INFO - Contract '800900000009szdAAA' has total renewals: 0
# 2024-12-27 11:36:37,071 - INFO - Contract '8006F000001TQvEQAW' has total renewals: 0
# 2024-12-27 11:36:37,072 - INFO - Contract '8006F000001Zc9qQAC' has total renewals: 0
# 2024-12-27 11:36:37,073 - INFO - Contract '800Sz000004D5kEIAS' has total renewals: 0
# 2024-12-27 11:36:37,075 - INFO - Contract '800C60000000L7dIAE' has total renewals: 600
# 2024-12-27 11:36:37,077 - INFO - Contract '8006F000000Sh1oQAC' has total renewals: 150000
# 2024-12-27 11:36:37,078 - INFO - Contract '8006F000001TR7dQAG' has total renewals: 6000
# 2024-12-27 11:36:37,079 - INFO - Contract '800C60000000L7OIAU' has total renewals: 600
# 2024-12-27 11:36:37,081 - INFO - Contract '800C60000000L7TIAU' has total renewals: 600
# 2024-12-27 11:36:37,083 - INFO - Contract '800Sz000004D16iIAC' has total renewals: 1800
# 2024-12-27 11:36:37,084 - INFO - Contract '8006F000001ZbjdQAC' has total renewals: 0
# 2024-12-27 11:36:37,086 - INFO - Contract '800Sz000004D16YIAS' has total renewals: 1800
# 2024-12-27 11:36:37,087 - INFO - Contract '8006F000001f32eQAA' has total renewals: 1347
# 2024-12-27 11:36:37,088 - INFO - Contract '8006F000001esrWQAQ' has total renewals: 5500
# 2024-12-27 11:36:37,089 - INFO - Contract '800900000009szYAAQ' has total renewals: 31462.6
# 2024-12-27 11:36:37,091 - INFO - Contract '8006F000001eu3oQAA' has total renewals: 12000
# 2024-12-27 11:36:37,094 - INFO - Contract '8006F000001a1pXQAQ' has total renewals: 10800
# 2024-12-27 11:36:37,095 - INFO - Contract '800Sz000005SmbcIAC' has total renewals: 6782
# 2024-12-27 11:36:37,097 - INFO - Contract '800C60000000eM4IAI' has total renewals: 3000
# 2024-12-27 11:36:37,099 - INFO - Contract '800Sz000004D5ipIAC' has total renewals: 1766.77
# 2024-12-27 11:36:37,100 - INFO - Contract '8002s000000cF7kAAE' has total renewals: 0
# 2024-12-27 11:36:37,101 - INFO - Contract '8002s000000cBdlAAE' has total renewals: 0
# 2024-12-27 11:36:37,102 - INFO - Contract '8006F000000SeDpQAK' has total renewals: 0
# 2024-12-27 11:36:37,103 - INFO - Contract '8002s000000cF9rAAE' has total renewals: 0
# 2024-12-27 11:36:37,104 - INFO - Contract '8002s000000m0DyAAI' has total renewals: 0
# 2024-12-27 11:36:37,105 - INFO - Contract '8006F000001a1pcQAA' has total renewals: 0
# 2024-12-27 11:36:37,107 - INFO - Contract '8002s000000m04sAAA' has total renewals: 600
# 2024-12-27 11:36:37,108 - INFO - Contract '8006F000001eu3tQAA' has total renewals: 0
# 2024-12-27 11:36:37,110 - INFO - Contract '800C60000000hWWIAY' has total renewals: 3960
# 2024-12-27 11:36:37,111 - INFO - Contract '8006F000000SgE6QAK' has total renewals: 1440
# 2024-12-27 11:36:37,113 - INFO - Contract '8002s000000cFLPAA2' has total renewals: 0
# 2024-12-27 11:36:37,114 - INFO - Contract '8002s000000cBgSAAU' has total renewals: 0
# 2024-12-27 11:36:37,115 - INFO - Contract '8002s000000XrtzAAC' has total renewals: 0
# 2024-12-27 11:36:37,117 - INFO - Contract '800C60000000PoVIAU' has total renewals: 150000
# 2024-12-27 11:36:37,118 - INFO - Contract '8006F000001ZcbGQAS' has total renewals: 0
# 2024-12-27 11:36:37,120 - INFO - Contract '8002s000000DEtbAAG' has total renewals: 1200
# 2024-12-27 11:36:37,121 - INFO - Contract '8002s000000cFGnAAM' has total renewals: 0
# 2024-12-27 11:36:37,122 - INFO - Contract '8002s000000cBhaAAE' has total renewals: 0
# 2024-12-27 11:36:37,124 - INFO - Contract '8002s000000cFGxAAM' has total renewals: 0
# 2024-12-27 11:36:37,125 - INFO - Contract '8002s000000cBgXAAU' has total renewals: 0
# 2024-12-27 11:36:37,127 - INFO - Contract '8002s000000cG2XAAU' has total renewals: 0
# 2024-12-27 11:36:37,129 - INFO - Contract '8002s000000cFGsAAM' has total renewals: 0
# 2024-12-27 11:36:37,130 - INFO - Contract '8006F000000SgW4QAK' has total renewals: 3937.5
# 2024-12-27 11:36:37,132 - INFO - Contract '8002s000000cFLKAA2' has total renewals: 0
# 2024-12-27 11:36:37,134 - INFO - Contract '8006F000000SgiEQAS' has total renewals: 0
# 2024-12-27 11:36:37,135 - INFO - Contract '8006F000000SgWEQA0' has total renewals: 6937.54
# 2024-12-27 11:36:37,136 - INFO - Contract '8002s000000cGm8AAE' has total renewals: 0
# 2024-12-27 11:36:37,137 - INFO - Contract '8006F0000014uPHQAY' has total renewals: 10100
# 2024-12-27 11:36:37,138 - INFO - Contract '8006F000000TWeJQAW' has total renewals: 140000
# 2024-12-27 11:36:37,141 - INFO - Contract '8006F00000152R0QAI' has total renewals: 0
# 2024-12-27 11:36:37,143 - INFO - Contract '8006F0000016ErkQAE' has total renewals: 14400
# 2024-12-27 11:36:37,144 - INFO - Contract '8006F0000016F0IQAU' has total renewals: 5250
# 2024-12-27 11:36:37,146 - INFO - Contract '8006F000001NPmFQAW' has total renewals: 0
# 2024-12-27 11:36:37,147 - INFO - Contract '8002s000000m0DcAAI' has total renewals: 0
# 2024-12-27 11:36:37,148 - INFO - Contract '8006F000001Tau8QAC' has total renewals: 0
# 2024-12-27 11:36:37,149 - INFO - Contract '8006F000001NM8ZQAW' has total renewals: 0
# 2024-12-27 11:36:37,150 - INFO - Contract '8006F0000016Fq4QAE' has total renewals: 6300
# 2024-12-27 11:36:37,152 - INFO - Contract '8006F000001A0tWQAS' has total renewals: 5600
# 2024-12-27 11:36:37,154 - INFO - Contract '800Sz000007czL3IAI' has total renewals: 4550
# 2024-12-27 11:36:37,156 - INFO - Contract '8006F000001ZcSdQAK' has total renewals: 0
# 2024-12-27 11:36:37,158 - INFO - Contract '8006F000001ZcawQAC' has total renewals: 6400
# 2024-12-27 11:36:37,159 - INFO - Contract '800Sz000007LYu3IAG' has total renewals: 500
# 2024-12-27 11:36:37,161 - INFO - Contract '800Sz000004CzYnIAK' has total renewals: 0
# 2024-12-27 11:36:37,162 - INFO - Contract '800C60000000TvYIAU' has total renewals: 20000
# 2024-12-27 11:36:37,164 - INFO - Contract '800Sz000004D16zIAC' has total renewals: 1766.77
# 2024-12-27 11:36:37,165 - INFO - Contract '8002s000000cG2hAAE' has total renewals: 0
# 2024-12-27 11:36:37,167 - INFO - Contract '8002s000000Xru0AAC' has total renewals: 0
# 2024-12-27 11:36:37,168 - INFO - Contract '8002s000000cBgcAAE' has total renewals: 0
# 2024-12-27 11:36:37,169 - INFO - Contract '8002s000000cBgDAAU' has total renewals: 0
# 2024-12-27 11:36:37,171 - INFO - Contract '8002s000000cBg8AAE' has total renewals: 0
# 2024-12-27 11:36:37,172 - INFO - Contract '8002s000000cBgNAAU' has total renewals: 0
# 2024-12-27 11:36:37,173 - INFO - Contract '8002s000000cFHCAA2' has total renewals: 0
# 2024-12-27 11:36:37,174 - INFO - Contract '8002s000000cFLUAA2' has total renewals: 0
# 2024-12-27 11:36:37,177 - INFO - Contract '8002s000000cFHMAA2' has total renewals: 0
# 2024-12-27 11:36:37,178 - INFO - Contract '8002s000000cG2NAAU' has total renewals: 0
# 2024-12-27 11:36:37,180 - INFO - Contract '8002s000000cBgIAAU' has total renewals: 0
# 2024-12-27 11:36:37,181 - INFO - Contract '8002s000000cFHRAA2' has total renewals: 0
# 2024-12-27 11:36:37,182 - INFO - Contract '8002s000000cFN7AAM' has total renewals: 2380
# 2024-12-27 11:36:37,183 - INFO - Contract '8002s000000cBniAAE' has total renewals: 0
# 2024-12-27 11:36:37,184 - INFO - Contract '8002s000000cFHHAA2' has total renewals: 0
# 2024-12-27 11:36:37,185 - INFO - Contract '8006F000000Sh1eQAC' has total renewals: 106000
# 2024-12-27 11:36:37,186 - INFO - Contract '8006F000000SspNQAS' has total renewals: 0
# 2024-12-27 11:36:37,187 - INFO - Contract '8006F0000009yxBQAQ' has total renewals: 15624
# 2024-12-27 11:36:37,188 - INFO - Contract '8002s000000m05CAAQ' has total renewals: 1800
# 2024-12-27 11:36:37,189 - INFO - Contract '8006F000000Sh1jQAC' has total renewals: 150000
# 2024-12-27 11:36:37,190 - INFO - Contract '8006F00000152QvQAI' has total renewals: 0
# 2024-12-27 11:36:37,191 - INFO - Contract '8006F000000Sl2FQAS' has total renewals: 7617
# 2024-12-27 11:36:37,193 - INFO - Contract '8006F000000oUIpQAM' has total renewals: 0
# 2024-12-27 11:36:37,195 - INFO - Contract '8006F000000XbrDQAS' has total renewals: 0
# 2024-12-27 11:36:37,197 - INFO - Contract '8006F000000nPLQQA2' has total renewals: 6000
# 2024-12-27 11:36:37,198 - INFO - Contract '8006F000000TWeTQAW' has total renewals: 140000
# 2024-12-27 11:36:37,199 - INFO - Contract '8006F000000Shv6QAC' has total renewals: 0
# 2024-12-27 11:36:37,200 - INFO - Contract '8006F0000016HrGQAU' has total renewals: 0
# 2024-12-27 11:36:37,201 - INFO - Contract '8006F0000014oa1QAA' has total renewals: 0
# 2024-12-27 11:36:37,202 - INFO - Contract '8006F000000Sh1ZQAS' has total renewals: 103000
# 2024-12-27 11:36:37,204 - INFO - Contract '8006F000000TWeOQAW' has total renewals: 140000
# 2024-12-27 11:36:37,205 - INFO - Contract '8006F0000016F0NQAU' has total renewals: 5250
# 2024-12-27 11:36:37,207 - INFO - Contract '8006F0000016ErpQAE' has total renewals: 0
# 2024-12-27 11:36:37,208 - INFO - Contract '8006F0000014rzrQAA' has total renewals: 0
# 2024-12-27 11:36:37,209 - INFO - Contract '8006F0000016FIHQA2' has total renewals: 6000
# 2024-12-27 11:36:37,210 - INFO - Contract '8006F000001ZcSTQA0' has total renewals: 0
# 2024-12-27 11:36:37,211 - INFO - Contract '8006F0000016NbQQAU' has total renewals: 5500
# 2024-12-27 11:36:37,212 - INFO - Contract '800C60000000TezIAE' has total renewals: 0
# 2024-12-27 11:36:37,214 - INFO - Contract '8006F000001ZcSnQAK' has total renewals: 0
# 2024-12-27 11:36:37,215 - INFO - Contract '800C60000000VYJIA2' has total renewals: 0
# 2024-12-27 11:36:37,217 - INFO - Contract '8006F000001Zcb1QAC' has total renewals: 0
# 2024-12-27 11:36:37,218 - INFO - Contract '8006F000001ZcbBQAS' has total renewals: 0
# 2024-12-27 11:36:37,219 - INFO - Contract '8002s000000lxNbAAI' has total renewals: 10000
# 2024-12-27 11:36:37,220 - INFO - Contract '8006F0000016FIWQA2' has total renewals: 3750
# 2024-12-27 11:36:37,221 - INFO - Contract '8006F000001ZcSJQA0' has total renewals: 0
# 2024-12-27 11:36:37,221 - INFO - Contract '800Sz000007stWXIAY' has total renewals: 0
# 2024-12-27 11:36:37,222 - INFO - Contract '800Sz000004CzZHIA0' has total renewals: 0
# 2024-12-27 11:36:37,223 - INFO - Contract '800C60000000e6TIAQ' has total renewals: 0
# 2024-12-27 11:36:37,224 - INFO - Contract '8006F0000016F0DQAU' has total renewals: 5250
# 2024-12-27 11:36:37,225 - INFO - Contract '800C60000000TQvIAM' has total renewals: 5000
# 2024-12-27 11:36:37,227 - INFO - Contract '8006F000001ZqmgQAC' has total renewals: 2520
# 2024-12-27 11:36:37,228 - INFO - Contract '800Sz000007cs9wIAA' has total renewals: 4550
# 2024-12-27 11:36:37,230 - INFO - Contract '800Sz000007d0qYIAQ' has total renewals: 4550
# 2024-12-27 11:36:37,231 - INFO - Contract '8006F000001a2nDQAQ' has total renewals: 7070
# 2024-12-27 11:36:37,232 - INFO - Contract '8006F000001ZeWpQAK' has total renewals: 2310
# 2024-12-27 11:36:37,233 - INFO - Contract '800Sz000004D5ixIAC' has total renewals: 1800
# 2024-12-27 11:36:37,234 - INFO - Contract '800Sz000004D5iyIAC' has total renewals: 1800
# 2024-12-27 11:36:37,235 - INFO - Contract '800Sz000007ctQvIAI' has total renewals: 4550
# 2024-12-27 11:36:37,236 - INFO - Contract '8002s000000cBghAAE' has total renewals: 0
# 2024-12-27 11:36:37,237 - INFO - Contract '8006F000000Sh1UQAS' has total renewals: 106000
# 2024-12-27 11:36:37,238 - INFO - Contract '8006F000001a4KXQAY' has total renewals: 185727
# 2024-12-27 11:36:37,240 - INFO - Contract '800Sz00000AWpD0IAL' has total renewals: 1628
# 2024-12-27 11:36:37,243 - INFO - Contract '800Sz000004CzZIIA0' has total renewals: 0
# 2024-12-27 11:36:37,246 - INFO - Contract '800C60000000XOrIAM' has total renewals: 600
# 2024-12-27 11:36:37,248 - INFO - Contract '8006F000000A1EvQAK' has total renewals: 5125
# 2024-12-27 11:36:37,251 - INFO - Contract '8002s000000cHRyAAM' has total renewals: 3900
# 2024-12-27 11:36:37,253 - INFO - Contract '8006F000000ShvBQAS' has total renewals: 0
# 2024-12-27 11:36:37,254 - INFO - Contract '8006F000000ShuGQAS' has total renewals: 4001
# 2024-12-27 11:36:37,255 - INFO - Contract '8002s000000cFQMAA2' has total renewals: 0
# 2024-12-27 11:36:37,256 - INFO - Contract '8002s000000cHRUAA2' has total renewals: 6000
# 2024-12-27 11:36:37,257 - INFO - Contract '8002s000000cFOjAAM' has total renewals: 0
# 2024-12-27 11:36:37,260 - INFO - Contract '8006F000000ShuKQAS' has total renewals: 4026.4799999999996
# 2024-12-27 11:36:37,263 - INFO - Contract '8006F000000ShuEQAS' has total renewals: 4944.48
# 2024-12-27 11:36:37,265 - INFO - Contract '8002s000000m0E1AAI' has total renewals: 0
# 2024-12-27 11:36:37,266 - INFO - Contract '8006F000000Shv5QAC' has total renewals: 0
# 2024-12-27 11:36:37,267 - INFO - Contract '8006F0000010k02QAA' has total renewals: 8000
# 2024-12-27 11:36:37,268 - INFO - Contract '8006F0000014oZzQAI' has total renewals: 0
# 2024-12-27 11:36:37,269 - INFO - Contract '8006F000000ShuLQAS' has total renewals: 4500
# 2024-12-27 11:36:37,270 - INFO - Contract '8006F0000014oZxQAI' has total renewals: 0
# 2024-12-27 11:36:37,271 - INFO - Contract '8002s000000cHrcAAE' has total renewals: 0
# 2024-12-27 11:36:37,273 - INFO - Contract '8006F0000014oa0QAA' has total renewals: 0
# 2024-12-27 11:36:37,274 - INFO - Contract '8006F000000XgDIQA0' has total renewals: 250
# 2024-12-27 11:36:37,278 - INFO - Contract '8006F0000014oa7QAA' has total renewals: 0
# 2024-12-27 11:36:37,279 - INFO - Contract '8006F0000016GRtQAM' has total renewals: 0
# 2024-12-27 11:36:37,280 - INFO - Contract '8006F0000014oZyQAI' has total renewals: 0
# 2024-12-27 11:36:37,281 - INFO - Contract '8006F0000014oaEQAQ' has total renewals: 0
# 2024-12-27 11:36:37,282 - INFO - Contract '8006F000001A8dmQAC' has total renewals: 250
# 2024-12-27 11:36:37,284 - INFO - Contract '8006F0000014oa6QAA' has total renewals: 0
# 2024-12-27 11:36:37,285 - INFO - Contract '8006F0000014oaBQAQ' has total renewals: 0
# 2024-12-27 11:36:37,286 - INFO - Contract '8006F000001TRA2QAO' has total renewals: 0
# 2024-12-27 11:36:37,287 - INFO - Contract '8006F0000016GqZQAU' has total renewals: 7000
# 2024-12-27 11:36:37,288 - INFO - Contract '8006F000001TRAHQA4' has total renewals: 0
# 2024-12-27 11:36:37,289 - INFO - Contract '8002s000000cFWtAAM' has total renewals: 93600
# 2024-12-27 11:36:37,290 - INFO - Contract '8006F000001TRjxQAG' has total renewals: 0
# 2024-12-27 11:36:37,292 - INFO - Contract '8006F000001TSgIQAW' has total renewals: 3300
# 2024-12-27 11:36:37,293 - INFO - Contract '8006F000001euEDQAY' has total renewals: 0
# 2024-12-27 11:36:37,294 - INFO - Contract '8006F000001euDoQAI' has total renewals: 0
# 2024-12-27 11:36:37,295 - INFO - Contract '8006F000001Taz3QAC' has total renewals: 4050
# 2024-12-27 11:36:37,297 - INFO - Contract '800C60000000e71IAA' has total renewals: 0
# 2024-12-27 11:36:37,298 - INFO - Contract '8006F000001euDyQAI' has total renewals: 0
# 2024-12-27 11:36:37,300 - INFO - Contract '800C60000000Yl7IAE' has total renewals: 1200
# 2024-12-27 11:36:37,301 - INFO - Contract '800C60000000er0IAA' has total renewals: 6000
# 2024-12-27 11:36:37,301 - INFO - Contract '800Sz00000AOh4TIAT' has total renewals: 1500
# 2024-12-27 11:36:37,302 - INFO - Contract '8006F0000016GqeQAE' has total renewals: 2250
# 2024-12-27 11:36:37,303 - INFO - Contract '8002s000000cBrgAAE' has total renewals: 0
# 2024-12-27 11:36:37,304 - INFO - Contract '8002s000000cBuzAAE' has total renewals: 0
# 2024-12-27 11:36:37,305 - INFO - Contract '8002s000000DDICAA4' has total renewals: 2880
# 2024-12-27 11:36:37,307 - INFO - Contract '8002s000000cFacAAE' has total renewals: 68401
# 2024-12-27 11:36:37,309 - INFO - Contract '8002s000000cFNWAA2' has total renewals: 0
# 2024-12-27 11:36:37,311 - INFO - Contract '8002s000000cFMTAA2' has total renewals: 0
# 2024-12-27 11:36:37,312 - INFO - Contract '8002s000000cFNlAAM' has total renewals: 0
# 2024-12-27 11:36:37,313 - INFO - Contract '8002s000000cHTzAAM' has total renewals: 0
# 2024-12-27 11:36:37,314 - INFO - Contract '8002s000000m0E0AAI' has total renewals: 0
# 2024-12-27 11:36:37,315 - INFO - Contract '8006F0000014oZvQAI' has total renewals: 0
# 2024-12-27 11:36:37,316 - INFO - Contract '8006F000000ShuDQAS' has total renewals: 9725
# 2024-12-27 11:36:37,318 - INFO - Contract '8006F000000ShuFQAS' has total renewals: 4500
# 2024-12-27 11:36:37,319 - INFO - Contract '8006F000000Shv4QAC' has total renewals: 0
# 2024-12-27 11:36:37,320 - INFO - Contract '8002s000000cFMOAA2' has total renewals: 14400
# 2024-12-27 11:36:37,321 - INFO - Contract '8006F000000ShuJQAS' has total renewals: 3150
# 2024-12-27 11:36:37,322 - INFO - Contract '8006F0000014oZwQAI' has total renewals: 0
# 2024-12-27 11:36:37,323 - INFO - Contract '8006F000000ShvAQAS' has total renewals: 0
# 2024-12-27 11:36:37,324 - INFO - Contract '8006F0000014mp0QAA' has total renewals: 0
# 2024-12-27 11:36:37,327 - INFO - Contract '8002s000000Xru1AAC' has total renewals: 0
# 2024-12-27 11:36:37,328 - INFO - Contract '8006F0000014oa5QAA' has total renewals: 0
# 2024-12-27 11:36:37,328 - INFO - Contract '8006F000000Shv9QAC' has total renewals: 0
# 2024-12-27 11:36:37,330 - INFO - Contract '8006F000000XgDrQAK' has total renewals: 250
# 2024-12-27 11:36:37,331 - INFO - Contract '8002s000000cFOoAAM' has total renewals: 0
# 2024-12-27 11:36:37,332 - INFO - Contract '8006F0000014oa8QAA' has total renewals: 0
# 2024-12-27 11:36:37,333 - INFO - Contract '8006F000001TR9wQAG' has total renewals: 0
# 2024-12-27 11:36:37,334 - INFO - Contract '8006F0000014oa4QAA' has total renewals: 0
# 2024-12-27 11:36:37,335 - INFO - Contract '8006F000001NPmGQAW' has total renewals: 0
# 2024-12-27 11:36:37,336 - INFO - Contract '8006F000001TRACQA4' has total renewals: 0
# 2024-12-27 11:36:37,337 - INFO - Contract '8006F000001TRA3QAO' has total renewals: 0
# 2024-12-27 11:36:37,339 - INFO - Contract '8006F0000016GqjQAE' has total renewals: 7000
# 2024-12-27 11:36:37,339 - INFO - Contract '8006F0000016GqoQAE' has total renewals: 3000
# 2024-12-27 11:36:37,341 - INFO - Contract '8006F000001TluFQAS' has total renewals: 0
# 2024-12-27 11:36:37,343 - INFO - Contract '8006F000001euE3QAI' has total renewals: 0
# 2024-12-27 11:36:37,345 - INFO - Contract '8006F000001euDjQAI' has total renewals: 0
# 2024-12-27 11:36:37,346 - INFO - Contract '800C60000000fsGIAQ' has total renewals: 0
# 2024-12-27 11:36:37,346 - INFO - Contract '8006F000001TkULQA0' has total renewals: 102727
# 2024-12-27 11:36:37,347 - INFO - Contract '8006F000001euDtQAI' has total renewals: 0
# 2024-12-27 11:36:37,348 - INFO - Contract '800C60000000LkhIAE' has total renewals: 0
# 2024-12-27 11:36:37,349 - INFO - Contract '800Sz000004BjifIAC' has total renewals: 0
# 2024-12-27 11:36:37,350 - INFO - Contract '8006F000001TkUGQA0' has total renewals: 130727
# 2024-12-27 11:36:37,352 - INFO - Contract '8006F000001TkC5QAK' has total renewals: 3529
# 2024-12-27 11:36:37,353 - INFO - Contract '8006F000001ZjUgQAK' has total renewals: 1728
# 2024-12-27 11:36:37,354 - INFO - Contract '800C60000000TvdIAE' has total renewals: 1400
# 2024-12-27 11:36:37,356 - INFO - Contract '800C60000000fsLIAQ' has total renewals: 0
# 2024-12-27 11:36:37,357 - INFO - Contract '800Sz00000CSCP7IAP' has total renewals: 110
# 2024-12-27 11:36:37,358 - INFO - Contract '800C60000000e6YIAQ' has total renewals: 0
# 2024-12-27 11:36:37,360 - INFO - Contract '8006F0000014qPLQAY' has total renewals: 49606
# 2024-12-27 11:36:37,362 - INFO - Contract '800C60000000WA8IAM' has total renewals: 3000
# 2024-12-27 11:36:37,363 - INFO - Contract '800C60000000YrJIAU' has total renewals: 1856
# 2024-12-27 11:36:37,364 - INFO - Contract '8006F000001TRAUQA4' has total renewals: 0
# 2024-12-27 11:36:37,365 - INFO - Contract '8006F0000014oaAQAQ' has total renewals: 0
# 2024-12-27 11:36:37,366 - INFO - Contract '8006F000001euE8QAI' has total renewals: 0
# 2024-12-27 11:36:37,367 - INFO - Contract '8006F000000Shv3QAC' has total renewals: 0
# 2024-12-27 11:36:37,369 - INFO - Contract '8006F000001ZdplQAC' has total renewals: 0
# 2024-12-27 11:36:37,370 - INFO - Contract '8006F000001TRA4QAO' has total renewals: 0
# 2024-12-27 11:36:37,370 - INFO - Contract '8006F000001A8dIQAS' has total renewals: 250
# 2024-12-27 11:36:37,371 - INFO - Contract '8006F000001TR9rQAG' has total renewals: 0
# 2024-12-27 11:36:37,372 - INFO - Contract '8006F000001TRjsQAG' has total renewals: 0
# 2024-12-27 11:36:37,373 - INFO - Contract '8002s000000cGvJAAU' has total renewals: 0
# 2024-12-27 11:36:37,375 - INFO - Contract '8002s000000cFX3AAM' has total renewals: 62400
# 2024-12-27 11:36:37,376 - INFO - Contract '8002s000000cBsUAAU' has total renewals: 0
# 2024-12-27 11:36:37,378 - INFO - Contract '8002s000000lyVnAAI' has total renewals: 977
# 2024-12-27 11:36:37,379 - INFO - Contract '8006F000000ShuTQAS' has total renewals: 4800
# 2024-12-27 11:36:37,380 - INFO - Contract '8006F0000014u95QAA' has total renewals: 7282
# 2024-12-27 11:36:37,381 - INFO - Contract '8006F000001TRASQA4' has total renewals: 0
# 2024-12-27 11:36:37,382 - INFO - Contract '800Sz0000018d3jIAA' has total renewals: 1800
# 2024-12-27 11:36:37,383 - INFO - Contract '8002s000000DDjYAAW' has total renewals: 0
# 2024-12-27 11:36:37,384 - INFO - Contract '8002s000000cBq4AAE' has total renewals: 900
# 2024-12-27 11:36:37,385 - INFO - Contract '8002s000000cDIIAA2' has total renewals: 500
# 2024-12-27 11:36:37,386 - INFO - Contract '8002s000000cFe0AAE' has total renewals: 0
# 2024-12-27 11:36:37,387 - INFO - Contract '8002s000000cFZWAA2' has total renewals: 0
# 2024-12-27 11:36:37,388 - INFO - Contract '8002s000000cBqEAAU' has total renewals: 900
# 2024-12-27 11:36:37,389 - INFO - Contract '8002s000000cFc4AAE' has total renewals: 0
# 2024-12-27 11:36:37,391 - INFO - Contract '8002s000000cFcsAAE' has total renewals: 2246
# 2024-12-27 11:36:37,392 - INFO - Contract '8002s000000cF7hAAE' has total renewals: 0
# 2024-12-27 11:36:37,394 - INFO - Contract '8002s000000lyWlAAI' has total renewals: 0
# 2024-12-27 11:36:37,396 - INFO - Contract '8002s000000lyX5AAI' has total renewals: 0
# 2024-12-27 11:36:37,398 - INFO - Contract '8002s000000lyXUAAY' has total renewals: 442
# 2024-12-27 11:36:37,400 - INFO - Contract '8006F000000ShuQQAS' has total renewals: 4000
# 2024-12-27 11:36:37,401 - INFO - Contract '8006F000000ShuOQAS' has total renewals: 6000
# 2024-12-27 11:36:37,402 - INFO - Contract '8006F000000ShvJQAS' has total renewals: 0
# 2024-12-27 11:36:37,404 - INFO - Contract '8006F000000ShvCQAS' has total renewals: 0
# 2024-12-27 11:36:37,404 - INFO - Contract '8006F000000ShvEQAS' has total renewals: 0
# 2024-12-27 11:36:37,405 - INFO - Contract '8006F000000nDrzQAE' has total renewals: 3000
# 2024-12-27 11:36:37,406 - INFO - Contract '8006F000000ShvDQAS' has total renewals: 0
# 2024-12-27 11:36:37,407 - INFO - Contract '8006F0000014m2qQAA' has total renewals: 0
# 2024-12-27 11:36:37,409 - INFO - Contract '8006F000000XnD1QAK' has total renewals: 0
# 2024-12-27 11:36:37,411 - INFO - Contract '8006F0000014mTsQAI' has total renewals: 0
# 2024-12-27 11:36:37,412 - INFO - Contract '8006F000000ShvFQAS' has total renewals: 0
# 2024-12-27 11:36:37,413 - INFO - Contract '8006F0000010lsHQAQ' has total renewals: 775
# 2024-12-27 11:36:37,415 - INFO - Contract '8006F0000016H4CQAU' has total renewals: 0
# 2024-12-27 11:36:37,416 - INFO - Contract '8006F000001A6iHQAS' has total renewals: 0
# 2024-12-27 11:36:37,417 - INFO - Contract '8006F0000014rqTQAQ' has total renewals: 0
# 2024-12-27 11:36:37,418 - INFO - Contract '8006F0000014u9FQAQ' has total renewals: 5400
# 2024-12-27 11:36:37,419 - INFO - Contract '8006F000001Zf22QAC' has total renewals: 0
# 2024-12-27 11:36:37,421 - INFO - Contract '8006F0000014u8gQAA' has total renewals: 0
# 2024-12-27 11:36:37,422 - INFO - Contract '800C60000000LAqIAM' has total renewals: 0
# 2024-12-27 11:36:37,424 - INFO - Contract '8006F0000016H3xQAE' has total renewals: 9720
# 2024-12-27 11:36:37,425 - INFO - Contract '800C60000000T8cIAE' has total renewals: 290
# 2024-12-27 11:36:37,427 - INFO - Contract '800C60000000LAlIAM' has total renewals: 972
# 2024-12-27 11:36:37,428 - INFO - Contract '8006F000001TRA9QAO' has total renewals: 0
# 2024-12-27 11:36:37,429 - INFO - Contract '8006F000001euENQAY' has total renewals: 0
# 2024-12-27 11:36:37,431 - INFO - Contract '8002s000000cBrWAAU' has total renewals: 0
# 2024-12-27 11:36:37,432 - INFO - Contract '8002s000000cBqxAAE' has total renewals: 0
# 2024-12-27 11:36:37,432 - INFO - Contract '8002s000000cBzSAAU' has total renewals: 0
# 2024-12-27 11:36:37,434 - INFO - Contract '8006F000001Zf1xQAC' has total renewals: 14400
# 2024-12-27 11:36:37,435 - INFO - Contract '8002s000000cBq9AAE' has total renewals: 900
# 2024-12-27 11:36:37,437 - INFO - Contract '8002s000000Xrl9AAC' has total renewals: 145660
# 2024-12-27 11:36:37,438 - INFO - Contract '8002s000000cBr2AAE' has total renewals: 0
# 2024-12-27 11:36:37,439 - INFO - Contract '8002s000000cC4uAAE' has total renewals: 0
# 2024-12-27 11:36:37,440 - INFO - Contract '8002s000000cBuuAAE' has total renewals: 0
# 2024-12-27 11:36:37,443 - INFO - Contract '8002s000000lyWvAAI' has total renewals: 0
# 2024-12-27 11:36:37,444 - INFO - Contract '8002s000000cCTpAAM' has total renewals: 0
# 2024-12-27 11:36:37,445 - INFO - Contract '8002s000000lyXPAAY' has total renewals: 0
# 2024-12-27 11:36:37,446 - INFO - Contract '8002s000000cH3eAAE' has total renewals: 0
# 2024-12-27 11:36:37,447 - INFO - Contract '8002s000000lyWqAAI' has total renewals: 0
# 2024-12-27 11:36:37,448 - INFO - Contract '8002s000000lyX0AAI' has total renewals: 442
# 2024-12-27 11:36:37,449 - INFO - Contract '8006F000000ShuNQAS' has total renewals: 2700
# 2024-12-27 11:36:37,450 - INFO - Contract '8006F000000ShuPQAS' has total renewals: 3150
# 2024-12-27 11:36:37,452 - INFO - Contract '8002s000000cBqsAAE' has total renewals: 62400
# 2024-12-27 11:36:37,453 - INFO - Contract '8006F000000ShuVQAS' has total renewals: 4026.4799999999996
# 2024-12-27 11:36:37,455 - INFO - Contract '8006F000000ShuMQAS' has total renewals: 3876.4799999999996
# 2024-12-27 11:36:37,456 - INFO - Contract '8002s000000lyWgAAI' has total renewals: 0
# 2024-12-27 11:36:37,457 - INFO - Contract '8006F0000014mCWQAY' has total renewals: 0
# 2024-12-27 11:36:37,459 - INFO - Contract '8006F000000ShvHQAS' has total renewals: 0
# 2024-12-27 11:36:37,460 - INFO - Contract '8006F000000nKzkQAE' has total renewals: 0
# 2024-12-27 11:36:37,461 - INFO - Contract '8006F000000ShuUQAS' has total renewals: 4026.4799999999996
# 2024-12-27 11:36:37,463 - INFO - Contract '8006F0000014u9AQAQ' has total renewals: 0
# 2024-12-27 11:36:37,464 - INFO - Contract '8006F000000ShvKQAS' has total renewals: 0
# 2024-12-27 11:36:37,466 - INFO - Contract '8006F000000ShvOQAS' has total renewals: 0
# 2024-12-27 11:36:37,467 - INFO - Contract '8006F000000ShvLQAS' has total renewals: 0
# 2024-12-27 11:36:37,468 - INFO - Contract '8002s000000cFcxAAE' has total renewals: 0
# 2024-12-27 11:36:37,468 - INFO - Contract '8006F0000014oa9QAA' has total renewals: 0
# 2024-12-27 11:36:37,469 - INFO - Contract '8006F0000014u9KQAQ' has total renewals: 0
# 2024-12-27 11:36:37,470 - INFO - Contract '8006F000001TRA8QAO' has total renewals: 0
# 2024-12-27 11:36:37,471 - INFO - Contract '8002s000000lyXZAAY' has total renewals: 0
# 2024-12-27 11:36:37,472 - INFO - Contract '8006F0000014mUCQAY' has total renewals: 0
# 2024-12-27 11:36:37,473 - INFO - Contract '8006F000000XgDcQAK' has total renewals: 250
# 2024-12-27 11:36:37,475 - INFO - Contract '8006F0000016MIhQAM' has total renewals: 7900
# 2024-12-27 11:36:37,476 - INFO - Contract '8006F0000014mTnQAI' has total renewals: 9120
# 2024-12-27 11:36:37,478 - INFO - Contract '8006F000001TR9tQAG' has total renewals: 0
# 2024-12-27 11:36:37,479 - INFO - Contract '8006F0000014u8qQAA' has total renewals: 0
# 2024-12-27 11:36:37,480 - INFO - Contract '800C60000000Y6rIAE' has total renewals: 0
# 2024-12-27 11:36:37,482 - INFO - Contract '8006F0000014m2lQAA' has total renewals: 2688
# 2024-12-27 11:36:37,483 - INFO - Contract '8002s000000lyXFAAY' has total renewals: 442
# 2024-12-27 11:36:37,484 - INFO - Contract '8006F0000016H47QAE' has total renewals: 0
# 2024-12-27 11:36:37,485 - INFO - Contract '8006F0000014u8bQAA' has total renewals: 5302
# 2024-12-27 11:36:37,486 - INFO - Contract '8006F0000016H42QAE' has total renewals: 6600
# 2024-12-27 11:36:37,487 - INFO - Contract '8006F000001TRAVQA4' has total renewals: 0
# 2024-12-27 11:36:37,489 - INFO - Contract '8006F0000016IaBQAU' has total renewals: 6000
# 2024-12-27 11:36:37,491 - INFO - Contract '8006F000001TR9hQAG' has total renewals: 0
# 2024-12-27 11:36:37,492 - INFO - Contract '8006F000000XgDwQAK' has total renewals: 250
# 2024-12-27 11:36:37,494 - INFO - Contract '8006F000001TRAQQA4' has total renewals: 0
# 2024-12-27 11:36:37,495 - INFO - Contract '8006F000001NMcjQAG' has total renewals: 62400
# 2024-12-27 11:36:37,496 - INFO - Contract '8006F0000014u8lQAA' has total renewals: 5940
# 2024-12-27 11:36:37,497 - INFO - Contract '8006F000000ShuRQAS' has total renewals: 3445.84
# 2024-12-27 11:36:37,498 - INFO - Contract '8006F0000016P3uQAE' has total renewals: 21920
# 2024-12-27 11:36:37,500 - INFO - Contract '8006F000000ShvGQAS' has total renewals: 0
# 2024-12-27 11:36:37,502 - INFO - Contract '8002s000000cBySAAU' has total renewals: 0
# 2024-12-27 11:36:37,504 - INFO - Contract '8006F000000ShuWQAS' has total renewals: 5251.68
# 2024-12-27 11:36:37,505 - INFO - Contract '800Sz000001M4duIAC' has total renewals: 2800
# 2024-12-27 11:36:37,506 - INFO - Contract '8002s000000cBrCAAU' has total renewals: 0
# 2024-12-27 11:36:37,507 - INFO - Contract '8002s000000cFjWAAU' has total renewals: 0
# 2024-12-27 11:36:37,509 - INFO - Contract '8006F000000ShudQAC' has total renewals: 3719.84
# 2024-12-27 11:36:37,510 - INFO - Contract '8002s000000lxJQAAY' has total renewals: 225
# 2024-12-27 11:36:37,511 - INFO - Contract '8006F000000ShubQAC' has total renewals: 3585.84
# 2024-12-27 11:36:37,512 - INFO - Contract '8006F000000ShvQQAS' has total renewals: 0
# 2024-12-27 11:36:37,514 - INFO - Contract '8006F000000ShuaQAC' has total renewals: 3600
# 2024-12-27 11:36:37,516 - INFO - Contract '8006F000000ShvNQAS' has total renewals: 0
# 2024-12-27 11:36:37,517 - INFO - Contract '8006F000000ShvMQAS' has total renewals: 0
# 2024-12-27 11:36:37,518 - INFO - Contract '8006F000000ShuYQAS' has total renewals: 2700
# 2024-12-27 11:36:37,518 - INFO - Contract '8006F000000TUI2QAO' has total renewals: 0
# 2024-12-27 11:36:37,519 - INFO - Contract '8006F000000ShvUQAS' has total renewals: 0
# 2024-12-27 11:36:37,520 - INFO - Contract '8006F000000ShvPQAS' has total renewals: 0
# 2024-12-27 11:36:37,521 - INFO - Contract '8006F000000TUnYQAW' has total renewals: 1300
# 2024-12-27 11:36:37,521 - INFO - Contract '8006F000000TVZrQAO' has total renewals: 7800
# 2024-12-27 11:36:37,522 - INFO - Contract '8006F000000ShvRQAS' has total renewals: 0
# 2024-12-27 11:36:37,524 - INFO - Contract '8002s000000m0DdAAI' has total renewals: 0
# 2024-12-27 11:36:37,526 - INFO - Contract '8006F000000XgDhQAK' has total renewals: 250
# 2024-12-27 11:36:37,528 - INFO - Contract '8006F000001TRA6QAO' has total renewals: 0
# 2024-12-27 11:36:37,529 - INFO - Contract '8006F0000016GyTQAU' has total renewals: 0
# 2024-12-27 11:36:37,530 - INFO - Contract '8006F0000014rzyQAA' has total renewals: 0
# 2024-12-27 11:36:37,531 - INFO - Contract '8006F000001TRAAQA4' has total renewals: 0
# 2024-12-27 11:36:37,532 - INFO - Contract '800Sz000001BueJIAS' has total renewals: 2400
# 2024-12-27 11:36:37,533 - INFO - Contract '8006F000001TRQtQAO' has total renewals: 0
# 2024-12-27 11:36:37,534 - INFO - Contract '8006F000000Xo8BQAS' has total renewals: 23920
# 2024-12-27 11:36:37,536 - INFO - Contract '8006F0000014triQAA' has total renewals: 0
# 2024-12-27 11:36:37,537 - INFO - Contract '8006F000000Sn2WQAS' has total renewals: 0
# 2024-12-27 11:36:37,538 - INFO - Contract '800Sz000001NU03IAG' has total renewals: 2200
# 2024-12-27 11:36:37,539 - INFO - Contract '8006F000001TSlXQAW' has total renewals: 8000
# 2024-12-27 11:36:37,539 - INFO - Contract '800Sz000001M4PPIA0' has total renewals: 0
# 2024-12-27 11:36:37,540 - INFO - Contract '8006F000001f1diQAA' has total renewals: 2150
# 2024-12-27 11:36:37,541 - INFO - Contract '8006F000001Tbp0QAC' has total renewals: 0
# 2024-12-27 11:36:37,543 - INFO - Contract '8006F000001ZtUxQAK' has total renewals: 4800
# 2024-12-27 11:36:37,544 - INFO - Contract '8002s000000cBxUAAU' has total renewals: 0
# 2024-12-27 11:36:37,545 - INFO - Contract '8002s000000cC54AAE' has total renewals: 0
# 2024-12-27 11:36:37,547 - INFO - Contract '8002s000000cC4kAAE' has total renewals: 1700
# 2024-12-27 11:36:37,549 - INFO - Contract '8002s000000cFmLAAU' has total renewals: 0
# 2024-12-27 11:36:37,550 - INFO - Contract '8002s000000DDi6AAG' has total renewals: 0
# 2024-12-27 11:36:37,551 - INFO - Contract '8002s000000DDhXAAW' has total renewals: 2941
# 2024-12-27 11:36:37,552 - INFO - Contract '8002s000000cFjgAAE' has total renewals: 0
# 2024-12-27 11:36:37,553 - INFO - Contract '8002s000000m0DeAAI' has total renewals: 0
# 2024-12-27 11:36:37,554 - INFO - Contract '8002s000000cFjjAAE' has total renewals: 0
# 2024-12-27 11:36:37,555 - INFO - Contract '8002s000000cBxKAAU' has total renewals: 0
# 2024-12-27 11:36:37,556 - INFO - Contract '8002s000000cHbNAAU' has total renewals: 0
# 2024-12-27 11:36:37,557 - INFO - Contract '8002s000000cFqnAAE' has total renewals: 0
# 2024-12-27 11:36:37,559 - INFO - Contract '8002s000000cCTkAAM' has total renewals: 0
# 2024-12-27 11:36:37,560 - INFO - Contract '8002s000000cFl8AAE' has total renewals: 68400
# 2024-12-27 11:36:37,562 - INFO - Contract '8006F000000TUHxQAO' has total renewals: 0
# 2024-12-27 11:36:37,564 - INFO - Contract '8006F000000ShuZQAS' has total renewals: 6000
# 2024-12-27 11:36:37,565 - INFO - Contract '8006F000000TUHsQAO' has total renewals: 0
# 2024-12-27 11:36:37,566 - INFO - Contract '8006F000000Xn6PQAS' has total renewals: 0
# 2024-12-27 11:36:37,567 - INFO - Contract '8006F000000TUHnQAO' has total renewals: 0
# 2024-12-27 11:36:37,569 - INFO - Contract '8006F000000ShujQAC' has total renewals: 5368.639999999999
# 2024-12-27 11:36:37,570 - INFO - Contract '8002s000000cEyKAAU' has total renewals: 3000
# 2024-12-27 11:36:37,571 - INFO - Contract '8006F000000TVZNQA4' has total renewals: 6700
# ...
# 2024-12-27 11:36:52,605 - INFO - Contract '800Sz00000D8RRlIAN' has total renewals: 800
# 2024-12-27 11:36:52,607 - INFO - Contract '800Sz00000D8JikIAF' has total renewals: 800
# 2024-12-27 11:36:52,609 - INFO - Contract '800Sz00000D8RzdIAF' has total renewals: 800
# 2024-12-27 11:36:52,611 - INFO - Contract '800Sz00000CLT8CIAX' has total renewals: 0
# 2024-12-27 11:36:52,612 - INFO - Contract '800Sz00000D8RbRIAV' has total renewals: 800
# 2024-12-27 11:36:52,614 - INFO - Contract '800Sz00000DF59cIAD' has total renewals: 0
# 2024-12-27 11:36:52,615 - INFO - Contract '800Sz00000DHwxlIAD' has total renewals: 1500
# 2024-12-27 11:36:52,617 - INFO - Contract '800Sz00000CQLEvIAP' has total renewals: 204
# 2024-12-27 11:36:52,619 - INFO - Contract '800Sz00000E9Qg2IAF' has total renewals: 715
# 2024-12-27 11:36:52,622 - INFO - Contract '800Sz00000E51xuIAB' has total renewals: 0
# 2024-12-27 11:36:52,623 - INFO - Contract '800Sz00000DgCOlIAN' has total renewals: 600
# 2024-12-27 11:36:52,625 - INFO - Contract '800Sz00000Eb371IAB' has total renewals: 0
# 2024-12-27 11:36:52,628 - INFO - Contract '800Sz00000DgMmGIAV' has total renewals: 1500
# 2024-12-27 11:36:52,630 - INFO - Contract '800Sz00000E9NiDIAV' has total renewals: 204
# 2024-12-27 11:36:52,632 - INFO - Contract '800Sz00000E9m0XIAR' has total renewals: 2450
# 2024-12-27 11:36:52,634 - INFO - Contract '800Sz00000EXWU8IAP' has total renewals: 0
# 2024-12-27 11:36:52,636 - INFO - Contract '800Sz00000DtDtEIAV' has total renewals: 0
# 2024-12-27 11:36:52,638 - INFO - Contract '800Sz00000EPzBYIA1' has total renewals: 1100
# 2024-12-27 11:36:52,640 - INFO - Contract '800Sz00000DT8VsIAL' has total renewals: 900
# 2024-12-27 11:36:52,642 - INFO - Contract '800Sz00000DgJJmIAN' has total renewals: 1500
# 2024-12-27 11:36:52,644 - INFO - Contract '800Sz00000DhfreIAB' has total renewals: 45000
# 2024-12-27 11:36:52,646 - INFO - Contract '800Sz00000EPSiiIAH' has total renewals: 1100
# 2024-12-27 11:36:52,648 - INFO - Contract '800Sz00000EQ9AwIAL' has total renewals: 1100
# 2024-12-27 11:36:52,650 - INFO - Contract '800Sz00000EPGPmIAP' has total renewals: 840
# 2024-12-27 11:36:52,653 - INFO - Contract '800Sz00000DgC6wIAF' has total renewals: 1500
# 2024-12-27 11:36:52,655 - INFO - Contract '800Sz00000EIGshIAH' has total renewals: 715
# 2024-12-27 11:36:52,656 - INFO - Contract '800Sz00000DgGsAIAV' has total renewals: 1500
# 2024-12-27 11:36:52,659 - INFO - Contract '800Sz00000EhvPfIAJ' has total renewals: 1350
# 2024-12-27 11:36:52,661 - INFO - Contract '800Sz00000EPob3IAD' has total renewals: 360
# 2024-12-27 11:36:52,663 - INFO - Contract '800Sz00000EPgFKIA1' has total renewals: 360
# 2024-12-27 11:36:52,665 - INFO - Contract '800Sz00000EXJdPIAX' has total renewals: 0
# 2024-12-27 11:36:52,666 - INFO - Contract '800Sz00000EAQu6IAH' has total renewals: 800
# 2024-12-27 11:36:52,668 - INFO - Contract '800Sz00000E9b9yIAB' has total renewals: 1350
# 2024-12-27 11:36:52,670 - INFO - Contract '800Sz00000D8KztIAF' has total renewals: 800
# 2024-12-27 11:36:52,672 - INFO - Contract '800Sz00000EAYwPIAX' has total renewals: 800
# 2024-12-27 11:36:52,674 - INFO - Contract '800Sz00000EATgcIAH' has total renewals: 0
# 2024-12-27 11:36:52,676 - INFO - Contract '800Sz00000F7zhFIAR' has total renewals: 235
# 2024-12-27 11:36:52,678 - INFO - Contract '800Sz00000ECbwbIAD' has total renewals: 1206
# 2024-12-27 11:36:52,679 - INFO - Contract '800Sz00000E9XpWIAV' has total renewals: 1350
# 2024-12-27 11:36:52,682 - INFO - Contract '800Sz00000D8M2IIAV' has total renewals: 800
# 2024-12-27 11:36:52,683 - INFO - Contract '800Sz00000ESqQEIA1' has total renewals: 0
# 2024-12-27 11:36:52,685 - INFO - Contract '800Sz00000E9JeXIAV' has total renewals: 715
# 2024-12-27 11:36:52,688 - INFO - Contract '800Sz00000F3vh6IAB' has total renewals: 4450
# 2024-12-27 11:36:52,690 - INFO - Contract '800Sz00000ENdQTIA1' has total renewals: 204
# 2024-12-27 11:36:52,692 - INFO - Contract '800Sz00000EAMaKIAX' has total renewals: 800
# 2024-12-27 11:36:52,693 - INFO - Contract '800Sz00000CuMJtIAN' has total renewals: 81
# 2024-12-27 11:36:52,695 - INFO - Contract '800Sz00000D8Mn5IAF' has total renewals: 800
# 2024-12-27 11:36:52,697 - INFO - Contract '800Sz00000EBvKhIAL' has total renewals: 204
# 2024-12-27 11:36:52,700 - INFO - Contract '800Sz00000EPXSAIA5' has total renewals: 33406.8
# 2024-12-27 11:36:52,702 - INFO - Contract '800Sz00000BDcsLIAT' has total renewals: 45000
# 2024-12-27 11:36:52,704 - INFO - Contract '80090000000UTnwAAG' has total renewals: 23560
# 2024-12-27 11:36:52,705 - INFO - Contract '800Sz00000ET54KIAT' has total renewals: 34632
# 2024-12-27 11:36:52,707 - INFO - Contract '8006F000000A1EqQAK' has total renewals: 1599
# 2024-12-27 11:36:52,709 - INFO - Contract '8006F0000014tjjQAA' has total renewals: 0
# 2024-12-27 11:36:52,711 - INFO - Contract '8006F000000nFiSQAU' has total renewals: 2500
# 2024-12-27 11:36:52,713 - INFO - Contract '8006F000001ZjpPQAS' has total renewals: 107400
# 2024-12-27 11:36:52,715 - INFO - Contract '8006F0000014tlaQAA' has total renewals: 0
# 2024-12-27 11:36:52,716 - INFO - Contract '8002s000000cG3iAAE' has total renewals: 0
# 2024-12-27 11:36:52,719 - INFO - Contract '80090000000USK0AAO' has total renewals: 18720
# 2024-12-27 11:36:52,722 - INFO - Contract '8006F000000WYPZQA4' has total renewals: 8400
# 2024-12-27 11:36:52,725 - INFO - Contract '80090000000UU9pAAG' has total renewals: 18040
# 2024-12-27 11:36:52,727 - INFO - Contract '8006F0000014tdzQAA' has total renewals: 0
# 2024-12-27 11:36:52,729 - INFO - Contract '8006F0000016KhzQAE' has total renewals: 0
# 2024-12-27 11:36:52,731 - INFO - Contract '80090000000UXRVAA4' has total renewals: 228000
# 2024-12-27 11:36:52,733 - INFO - Contract '80090000000UTjQAAW' has total renewals: 33496
# 2024-12-27 11:36:52,734 - INFO - Contract '80090000000UUAvAAO' has total renewals: 21350
# 2024-12-27 11:36:52,736 - INFO - Contract '800Sz00000DiDLRIA3' has total renewals: 60000
# 2024-12-27 11:36:52,738 - INFO - Contract '8006F000001A0tbQAC' has total renewals: 900
# 2024-12-27 11:36:52,741 - INFO - Contract '80090000000UZJOAA4' has total renewals: 198000
# 2024-12-27 11:36:52,742 - INFO - Contract '80090000000UUMmAAO' has total renewals: 8790
# 2024-12-27 11:36:52,744 - INFO - Contract '80090000000UYEIAA4' has total renewals: 27700
# 2024-12-27 11:36:52,746 - INFO - Contract '8002s000000XsFNAA0' has total renewals: 0
# 2024-12-27 11:36:52,748 - INFO - Contract '80090000000UXQIAA4' has total renewals: 19650
# 2024-12-27 11:36:52,750 - INFO - Contract '80090000000UXKFAA4' has total renewals: 15168
# 2024-12-27 11:36:52,751 - INFO - Contract '80090000000UXCfAAO' has total renewals: 15825
# 2024-12-27 11:36:52,752 - INFO - Contract '80090000000UUIpAAO' has total renewals: 20600
# 2024-12-27 11:36:52,753 - INFO - Contract '80090000000UUB5AAO' has total renewals: 18840
# 2024-12-27 11:36:52,755 - INFO - Contract '80090000000UZJdAAO' has total renewals: 198000
# 2024-12-27 11:36:52,758 - INFO - Contract '80090000000UZJnAAO' has total renewals: 228000
# 2024-12-27 11:36:52,760 - INFO - Contract '800C60000000Qw5IAE' has total renewals: 30000
# 2024-12-27 11:36:52,762 - INFO - Contract '8002s000000DCUEAA4' has total renewals: 7700
# 2024-12-27 11:36:52,764 - INFO - Contract '80090000000VTlfAAG' has total renewals: 18057
# 2024-12-27 11:36:52,766 - INFO - Contract '800C60000000St9IAE' has total renewals: 900
# 2024-12-27 11:36:52,768 - INFO - Contract '800C60000000Z4FIAU' has total renewals: 0
# 2024-12-27 11:36:52,770 - INFO - Contract '80090000000UdZSAA0' has total renewals: 8590
# 2024-12-27 11:36:52,772 - INFO - Contract '80090000000UbDTAA0' has total renewals: 22500
# 2024-12-27 11:36:52,774 - INFO - Contract '80090000000UVdFAAW' has total renewals: 10000
# 2024-12-27 11:36:52,776 - INFO - Contract '800Sz00000ECb71IAD' has total renewals: 0
# 2024-12-27 11:36:52,778 - INFO - Contract '80090000000UZczAAG' has total renewals: 0
# 2024-12-27 11:36:52,780 - INFO - Contract '800Sz00000D8LxWIAV' has total renewals: 800
# 2024-12-27 11:36:52,783 - INFO - Contract '800Sz0000084FjpIAE' has total renewals: 2400
# 2024-12-27 11:36:52,784 - INFO - Contract '80090000000UeydAAC' has total renewals: 15600
# 2024-12-27 11:36:52,786 - INFO - Contract '800Sz00000EPS7WIAX' has total renewals: 840
# 2024-12-27 11:36:52,788 - INFO - Contract '800Sz00000EPbqpIAD' has total renewals: 750
# 2024-12-27 11:36:52,790 - INFO - Contract '80090000000UeynAAC' has total renewals: 15000
# 2024-12-27 11:36:52,792 - INFO - Contract '80090000000UfarAAC' has total renewals: 16140
# 2024-12-27 11:36:52,794 - INFO - Contract '80090000000UtknAAC' has total renewals: 169827
# 2024-12-27 11:36:52,796 - INFO - Contract '800Sz00000FD8TnIAL' has total renewals: 1350
# 2024-12-27 11:36:52,798 - INFO - Contract '800Sz00000FDQk1IAH' has total renewals: 204
# 2024-12-27 11:36:52,800 - INFO - Contract '800Sz00000F7nGKIAZ' has total renewals: 235
# 2024-12-27 11:36:52,802 - INFO - Contract '800Sz00000F5adKIAR' has total renewals: 0
# 2024-12-27 11:36:52,804 - INFO - Contract '800Sz00000EVNhpIAH' has total renewals: 330
# 2024-12-27 11:36:52,806 - INFO - Contract '800Sz00000DgBPYIA3' has total renewals: 600
# 2024-12-27 11:36:52,808 - INFO - Contract '800Sz00000EPMi8IAH' has total renewals: 204
# 2024-12-27 11:36:52,809 - INFO - Contract '800Sz00000EDBlcIAH' has total renewals: 1500
# 2024-12-27 11:36:52,811 - INFO - Contract '800Sz00000EVXVuIAP' has total renewals: 0
# 2024-12-27 11:36:52,813 - INFO - Contract '800Sz00000EQEDtIAP' has total renewals: 900
# 2024-12-27 11:36:52,816 - INFO - Contract '800Sz00000EA9uvIAD' has total renewals: 800
# 2024-12-27 11:36:52,819 - INFO - Contract '800Sz00000EiGM2IAN' has total renewals: 1200
# 2024-12-27 11:36:52,831 - INFO - Contract '800Sz00000D8GmjIAF' has total renewals: 800
# 2024-12-27 11:36:52,834 - INFO - Contract '800Sz00000EjNlBIAV' has total renewals: 500
# 2024-12-27 11:36:52,836 - INFO - Contract '800Sz00000Eas0JIAR' has total renewals: 45000
# 2024-12-27 11:36:52,839 - INFO - Contract '800Sz00000EpHMvIAN' has total renewals: 1763
# 2024-12-27 11:36:52,841 - INFO - Contract '800Sz00000E9lm1IAB' has total renewals: 4900
# 2024-12-27 11:36:52,842 - INFO - Contract '800Sz00000F7oAjIAJ' has total renewals: 395
# 2024-12-27 11:36:52,844 - INFO - Contract '800Sz00000F3zZRIAZ' has total renewals: 4450
# 2024-12-27 11:36:52,846 - INFO - Contract '800Sz00000F5RLWIA3' has total renewals: 250
# 2024-12-27 11:36:52,850 - INFO - Contract '800Sz00000EjMqjIAF' has total renewals: 500
# 2024-12-27 11:36:52,852 - INFO - Contract '800Sz00000F8VcJIAV' has total renewals: 550
# 2024-12-27 11:36:52,853 - INFO - Contract '800Sz00000EqsPHIAZ' has total renewals: 24000
# 2024-12-27 11:36:52,854 - INFO - Contract '800Sz00000F3xUNIAZ' has total renewals: 4450
# 2024-12-27 11:36:52,857 - INFO - Contract '800Sz00000FD62BIAT' has total renewals: 204
# 2024-12-27 11:36:52,859 - INFO - Contract '800Sz00000FOvapIAD' has total renewals: 204
# 2024-12-27 11:36:52,861 - INFO - Contract '800Sz00000EXHRrIAP' has total renewals: 250
# 2024-12-27 11:36:52,863 - INFO - Contract '800Sz00000EPPCtIAP' has total renewals: 840
# 2024-12-27 11:36:52,864 - INFO - Contract '800Sz00000EXLLlIAP' has total renewals: 250
# 2024-12-27 11:36:52,867 - INFO - Contract '800Sz00000F3v60IAB' has total renewals: 4450
# 2024-12-27 11:36:52,869 - INFO - Contract '800Sz00000EpDPnIAN' has total renewals: 1840
# 2024-12-27 11:36:52,871 - INFO - Contract '800Sz00000FFWF3IAP' has total renewals: 360
# 2024-12-27 11:36:52,874 - INFO - Contract '800Sz00000FPDBAIA5' has total renewals: 650
# 2024-12-27 11:36:52,875 - INFO - Contract '800Sz00000GR1oPIAT' has total renewals: 400
# 2024-12-27 11:36:52,876 - INFO - Contract '800Sz00000FLDHmIAP' has total renewals: 204
# 2024-12-27 11:36:52,877 - INFO - Contract '80090000000UUIfAAO' has total renewals: 18240
# 2024-12-27 11:36:52,880 - INFO - Contract '800Sz00000FTlKhIAL' has total renewals: 204
# 2024-12-27 11:36:52,883 - INFO - Contract '800Sz00000FnaT9IAJ' has total renewals: 250
# 2024-12-27 11:36:52,885 - INFO - Contract '80090000000UZJJAA4' has total renewals: 228000
# 2024-12-27 11:36:52,891 - INFO - Contract '800Sz00000GVpEmIAL' has total renewals: 33000
# 2024-12-27 11:36:52,893 - INFO - Contract '800Sz00000FhlUVIAZ' has total renewals: 540
# 2024-12-27 11:36:52,895 - INFO - Contract '800Sz00000FOaxlIAD' has total renewals: 45000
# 2024-12-27 11:36:52,898 - INFO - Contract '800Sz00000Ep7vUIAR' has total renewals: 1840
# 2024-12-27 11:36:52,899 - INFO - Contract '800Sz00000DHr6sIAD' has total renewals: 1500
# 2024-12-27 11:36:52,901 - INFO - Contract '800Sz00000D8RWbIAN' has total renewals: 800
# 2024-12-27 11:36:52,903 - INFO - Contract '80090000000UbPoAAK' has total renewals: 397200
# 2024-12-27 11:36:52,906 - INFO - Contract '800Sz00000FqQQoIAN' has total renewals: 900
# 2024-12-27 11:36:52,907 - INFO - Contract '80090000000UewmAAC' has total renewals: 640000
# 2024-12-27 11:36:52,909 - INFO - Contract '80090000000Uf0UAAS' has total renewals: 640000
# 2024-12-27 11:36:52,911 - INFO - Contract '80090000000UewhAAC' has total renewals: 680000
# 2024-12-27 11:36:52,913 - INFO - Contract '800Sz00000FB67tIAD' has total renewals: 715
# 2024-12-27 11:36:52,915 - INFO - Contract '800Sz00000G47OMIAZ' has total renewals: 400
# 2024-12-27 11:36:52,917 - INFO - Contract '800Sz00000Fl4aeIAB' has total renewals: 1600
# 2024-12-27 11:36:52,919 - INFO - Contract '800Sz00000GNbCDIA1' has total renewals: 45000
# 2024-12-27 11:36:52,920 - INFO - Contract '800Sz00000GhG8NIAV' has total renewals: 1061
# 2024-12-27 11:36:52,922 - INFO - Contract '800Sz00000FWGSVIA5' has total renewals: 500
# 2024-12-27 11:36:52,924 - INFO - Contract '800Sz00000GQEfiIAH' has total renewals: 400
# 2024-12-27 11:36:52,926 - INFO - Contract '800Sz00000FhVb3IAF' has total renewals: 4800
# 2024-12-27 11:36:52,928 - INFO - Contract '800Sz00000FXUhpIAH' has total renewals: 1900
# 2024-12-27 11:36:52,930 - INFO - Contract '800Sz00000GQvkcIAD' has total renewals: 400
# 2024-12-27 11:36:52,932 - INFO - Contract '800Sz00000FhBR9IAN' has total renewals: 65000
# 2024-12-27 11:36:52,933 - INFO - Contract '800Sz00000G4PReIAN' has total renewals: 400
# 2024-12-27 11:36:52,936 - INFO - Contract '800Sz00000GQxJOIA1' has total renewals: 400
# 2024-12-27 11:36:52,938 - INFO - Contract '800Sz00000FpTnMIAV' has total renewals: 550
# 2024-12-27 11:36:52,940 - INFO - Contract '800Sz00000H3JKhIAN' has total renewals: 2000
# 2024-12-27 11:36:52,941 - INFO - Contract '800Sz00000EYXBHIA5' has total renewals: 200
# 2024-12-27 11:36:52,944 - INFO - Contract '800Sz00000GcmLlIAJ' has total renewals: 1500
# 2024-12-27 11:36:52,946 - INFO - Contract '800Sz00000GemsoIAB' has total renewals: 1400
# 2024-12-27 11:36:52,948 - INFO - Contract '800Sz00000H3JHLIA3' has total renewals: 500
# 2024-12-27 11:36:52,950 - INFO - Contract '800Sz00000G4O8zIAF' has total renewals: 16000
# 2024-12-27 11:36:52,953 - INFO - Contract '800Sz00000GvHqzIAF' has total renewals: 45000
# 2024-12-27 11:36:52,954 - INFO - Contract '800Sz00000I6CTxIAN' has total renewals: 0
# 2024-12-27 11:36:52,956 - INFO - Contract '800Sz00000I9SVnIAN' has total renewals: 0
# 2024-12-27 11:36:52,958 - INFO - Contract '800Sz00000I5ol3IAB' has total renewals: 0
# 2024-12-27 11:36:52,959 - INFO - Contract '800Sz00000I67quIAB' has total renewals: 0
# 2024-12-27 11:36:52,962 - INFO - Contract '800C60000000PR2IAM' has total renewals: 1800
# 2024-12-27 11:36:52,964 - INFO - Contract '800Sz00000AAqyxIAD' has total renewals: 331
# 2024-12-27 11:36:52,966 - INFO - Contract '800Sz00000AApLHIA1' has total renewals: 331
# 2024-12-27 11:36:52,968 - INFO - Contract '800C60000000KxWIAU' has total renewals: 49440
# 2024-12-27 11:36:53,137 - INFO - Calculated 'actual_contract_value_today' for contracts.
# 2024-12-27 11:36:53,143 - INFO - Milestone penalties are not applied as per user input.
# 2024-12-27 11:36:53,404 - INFO - Calculated 'final_interference_score' for contracts, including milestone penalties if applied.
# 2024-12-27 11:36:53,409 - INFO - Assigned 'final_rating' based on interference scores.
# 2024-12-27 11:37:02,633 - INFO - Processed data saved to Excel: C:\\Users\\ak012\\Documents\\Projects\\Contracts\\processed_contracts.xlsx
# 2024-12-27 11:37:02,876 - INFO - Closed MongoDB connection.
